# %% [markdown]
# # 5-assignment(EDA-1)

# %% [markdown]
# ### Data cleaning and preparation

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings 
warnings.simplefilter("ignore")

# %%
#reading the csv file  aka uploading
df = pd.read_csv("Cardiotocographic.csv")
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2106.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.270154     0.004391     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000142     0.000840    18.813973     1.173632    21.205041
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
df.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
num_cols_with_miss_values = ['LB','AC','DS','DP','MLTV','Width','Tendency','NSP']
for columns in num_cols_with_miss_values:
    mean_value = df[columns].mean()
    df[columns].fillna(mean_value,inplace=True)

# %%
df.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
df.dtypes
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
num_columns = df.select_dtypes(include=['float64','int64']).columns
num_columns
# Out:
# Index(['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV',
#        'MLTV', 'Width', 'Tendency', 'NSP'],
#       dtype='object')

# %%
for column in num_columns:
    Q1=df[column].quantile(0.25)
    Q3=df[column].quantile(0.75)
    IQR=Q3-Q1
    l_bound=Q1-1.5*IQR
    u_bound=Q3+1.5*IQR
    outliers=df[(df[column]<l_bound)|(df[column]>u_bound)]
    if len(outliers):
        print(f'The Outliers present in column {column} are :')
        print(outliers[[column]])
# Out:
# The Outliers present in column LB are :
#               LB
# 134    52.000000
# 411   214.000000
# 610   214.000000
# 612   214.000000
# 785    52.000000
# 1027   51.842487
# 1103  214.000000
# 1406  214.000000
# 1504  214.000000
# 1834   52.188547
# The Outliers present in column AC are :
#             AC
# 8     0.038567
# 23   -0.019284
# 83    0.014706
# 85    0.014230
# 116   0.038567
# 157  -0.019284
# 181   0.017241
# 496   0.014178
# 497   0.015552
# 498   0.015258
# 500   0.014178
# 501   0.014726
# 526   0.015013
# 527   0.014065
# 529   0.019284
# 530   0.015590
# 531   0.016423
# 552   0.015782
# 616   0.014806
# 626   0.038567
# 630   0.017391
# 681  -0.019284
# 999   0.014024
# 1000  0.014907
# 1066  0.014303
# 1093  0.015642
# 1094  0.017668
# 1096  0.017341
# 1231  0.038567
# 1248  0.017857
# 1311  0.014320
# 1312  0.015113
# 1687  0.014400
# 1752 -0.019284
# 1857  0.014068
# 1858  0.015907
# 1859  0.017073
# 1860  0.015166
# 1861  0.014444
# 1862  0.016000
# ...

# %%
df=df[(df[column]>=l_bound)&(df[column]<=u_bound)]
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# 12    131.000000  0.005076  0.072335  0.007614  0.002538  0.0  0.0  28.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2117  140.000000  0.000000  0.000000  0.007812  0.000000  0.0  0.0  79.0
# 2118  140.000000  0.000000  0.000000  0.006470  0.000898  0.0  0.0  79.0
# 2119  140.000000  0.000000  0.000000  0.006764  0.001127  0.0  0.0  79.0
# 2120  140.000000  0.000000  0.000000  0.004975  0.001244  0.0  0.0  77.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency  NSP
# ...

# %%
df.reset_index(inplace= True)
df
# Out:
#       index          LB        AC        FM        UC        DL   DS   DP  \
# 0         1  132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0
# 1         2  133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0
# 2         3  134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0
# 3         4  131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0
# 4        12  131.000000  0.005076  0.072335  0.007614  0.002538  0.0  0.0
# ...     ...         ...       ...       ...       ...       ...  ...  ...
# 1541   2117  140.000000  0.000000  0.000000  0.007812  0.000000  0.0  0.0
# 1542   2118  140.000000  0.000000  0.000000  0.006470  0.000898  0.0  0.0
# 1543   2119  140.000000  0.000000  0.000000  0.006764  0.001127  0.0  0.0
# 1544   2120  140.000000  0.000000  0.000000  0.004975  0.001244  0.0  0.0
# 1545   2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0
#
#       ASTV  MSTV       ALTV  MLTV  Width  Tendency  NSP
# ...

# %%
df.drop('index',axis=1,inplace=True)
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 1     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 2     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 3     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# 4     131.000000  0.005076  0.072335  0.007614  0.002538  0.0  0.0  28.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 1541  140.000000  0.000000  0.000000  0.007812  0.000000  0.0  0.0  79.0
# 1542  140.000000  0.000000  0.000000  0.006470  0.000898  0.0  0.0  79.0
# 1543  140.000000  0.000000  0.000000  0.006764  0.001127  0.0  0.0  79.0
# 1544  140.000000  0.000000  0.000000  0.004975  0.001244  0.0  0.0  77.0
# 1545  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency  NSP
# ...

# %% [markdown]
# ### statistical summary

# %%
stat_sum= df.describe()
stat_sum
# Out:
#                 LB           AC           FM           UC           DL  \
# count  1546.000000  1546.000000  1546.000000  1546.000000  1546.000000
# mean    131.919815     0.004063     0.007579     0.004829     0.001920
# std      11.115063     0.004393     0.054729     0.003313     0.003111
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     125.000000     0.000000     0.000000     0.002788     0.000000
# 50%     132.000000     0.002973     0.000000     0.004881     0.000000
# 75%     138.000000     0.006672     0.001987     0.006816     0.003534
# max     214.000000     0.038567     0.961268     0.030002     0.030621
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  1546.000000  1546.000000  1546.000000  1546.000000  1546.000000
# mean     -0.000003     0.000077    42.207271     1.461245     5.455809
# std       0.000111     0.000683    17.422340     1.116480    15.659211
# ...

# %% [markdown]
# ### Data visualization

# %%
df.hist(figsize=(18,12))
plt.show()

# %%
df.boxplot(figsize=(18,12))
plt.show()

# %%
plt.figure(figsize=(15,8))
core_matrix = df.corr()
sns.heatmap(core_matrix,annot=True,)
plt.show()

# %%
sns.pairplot(df)

# %% [markdown]
# ### Pattern Recoginsation and finding the insights

# %%
better_co = core_matrix[(core_matrix>0.5) & (core_matrix)]
better_co
# Out:
#            LB   AC   FM   UC   DL   DS   DP  ASTV  MSTV  ALTV  MLTV  Width  \
# LB        1.0  NaN  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN    NaN
# AC        NaN  1.0  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN    NaN
# FM        NaN  NaN  1.0  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN    NaN
# UC        NaN  NaN  NaN  1.0  NaN  NaN  NaN   NaN   NaN   NaN   NaN    NaN
# DL        NaN  NaN  NaN  NaN  1.0  NaN  NaN   NaN   NaN   NaN   NaN    NaN
# DS        NaN  NaN  NaN  NaN  NaN  1.0  NaN   NaN   NaN   NaN   NaN    NaN
# DP        NaN  NaN  NaN  NaN  NaN  NaN  1.0   NaN   NaN   NaN   NaN    NaN
# ASTV      NaN  NaN  NaN  NaN  NaN  NaN  NaN   1.0   NaN   NaN   NaN    NaN
# MSTV      NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN   1.0   NaN   NaN    NaN
# ALTV      NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN   NaN   1.0   NaN    NaN
# MLTV      NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   1.0    NaN
# ...

# %% [markdown]
# ### Conclusion

# %% [markdown]
# #### Theres no such specific trends in data ,but features MLTV ,width ,and UC data points are not widely distributed

# %% [markdown]
# ####
# Handling Missing Values:
# Null values were imputed with the mean values of the respective columns.
# Outlier Detection and Removal:
# Outliers were identified using the Interquartile Range (IQR) method and subsequently removed from the dataset.
# Correlation Analysis:
# The correlation matrix was calculated using the corr() function, which provides values between -1 and 1, indicating the strength and direction of relationships between variables.
# A heatmap was generated to visually represent the correlation matrix.
# #### Findings:
# The analysis revealed a generally low correlation between the variables within the dataset.
# Implications: This information is valuable for subsequent decision-making and model development. For instance, if variables exhibit low correlation.
# it suggests that:
#
# #### Feature Engineering:
# Techniques like creating new features or transforming existing ones might be necessary to enhance model performance.
# #### Model Selection:
# Models that are less sensitive to multicollinearity, such as decision trees or support vector machines, might be more suitable.
